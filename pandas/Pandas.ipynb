# %%
import pandas as pd

# %%
df = pd.read_csv('ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
print(type(df))
print(type(df['a']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
list(df['a'])
# Out:
# [1, 5, 9]

# %%
df.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df.tail(2)
# Out:
#    a   b   c   d message
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df  = pd.read_table('test.tsv')
df
# Out:
#     t   t1   t2  t3
# 0  af  afa  afa  af
# 1  sa  san  san  sa

# %%
df  = pd.read_csv('test.tsv', sep='\t')
df
# Out:
#     t   t1   t2  t3
# 0  af  afa  afa  af
# 1  sa  san  san  sa

# %%
df  = pd.read_table('ex1.csv', sep=',', header=None, names=['col1', 'col2', 'col3', 'col4' , 'col5', 'col6'])
df
# Out:
#   col1 col2 col3 col4     col5  col6
# 0    a    b    c    d  message   NaN
# 1    1    2    3    4    hello   NaN
# 2    5    6    7    8    world   NaN
# 3    9   10   11   12      foo   NaN

# %%
# header - no header (None), infer (consider first row header - default)
# sep
# names =array of col names if header is None
df  = pd.read_table('ex1.csv', sep=',', header=None, names=['col1', 'col2', 'col3', ])
df
# Out:
#      col1 col2     col3
# a b     c    d  message
# 1 2     3    4    hello
# 5 6     7    8    world
# 9 10   11   12      foo

# %%
# usecols - pick a column
df  = pd.read_table('ex1.csv', sep=',', header=None, names=['col1', 'col2', 'col3', 'col4', 'col5'], usecols=['col1', 'col2'])
df
# Out:
#   col1 col2
# 0    a    b
# 1    1    2
# 2    5    6
# 3    9   10

# %%
# index_col - column index for grouping - uniquely identify rows --- MultiIndex
p = pd.read_csv('ex2.csv', index_col=['key1', 'key2'])
p
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      c          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      c         15      16

# %%
p.index
# Out:
# MultiIndex([('one', 'a'),
#             ('one', 'b'),
#             ('one', 'c'),
#             ('one', 'c'),
#             ('two', 'a'),
#             ('two', 'b'),
#             ('two', 'c'),
#             ('two', 'c')],
#            names=['key1', 'key2'])

# %%
# skiprows - To skip the rows
pd.read_csv('ex2.csv', skiprows=[2,3])
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    c       7       8
# 2  two    a       9      10
# 3  two    b      11      12
# 4  two    c      13      14
# 5  two    c      15      16

# %%
df = pd.read_csv('ex3.csv')
# pd.isnull(df).sum()
df.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False     True

# %%
pd.read_csv('ex3.csv', na_values=['NULL'])
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
pd.read_excel('excel.xlsx', sheet_name='Sheet1')
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   7   world
# 2           2  9  10  11  12     foo

# %%
ht = pd.read_html('http://basketball-reference.com/leagues/NBA_2015_totals.html')
ht[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
ht[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
titanic_train = pd.read_csv("titanic.csv")   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic_train[['PassengerId', 'Pclass']]
# Out:
#      PassengerId  Pclass
# 0            892       3
# 1            893       3
# 2            894       2
# 3            895       3
# 4            896       3
# ..           ...     ...
# 413         1305       3
# 414         1306       1
# 415         1307       3
# 416         1308       3
# 417         1309       3
#
# [418 rows x 2 columns]

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.shape
# Out:
# (418, 12)

# %%
pd.read_csv("titanic.csv", nrows=5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare  Cabin Embarked
# 0   330911   7.8292    NaN        Q
# 1   363272   7.0000    NaN        S
# 2   240276   9.6875    NaN        Q
# 3   315154   8.6625    NaN        S
# 4  3101298  12.2875    NaN        S

# %%
chunk = pd.read_csv("titanic.csv", chunksize=100)
chunk

# %%
for i in chunk:
    print(i)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 95          987         0       3
# 96          988         1       1
# 97          989         0       3
# 98          990         1       3
# 99          991         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                                ...     ...   ...    ...
# ...

# %%
chunk.read()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df = pd.read_csv('ex3.csv')
df.to_csv('out.csv', sep='@')
# to_exec

# %%
import sys
df.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,NULL

# %%
df = pd.read_csv('ex3.csv')
# index and header removed
df.to_csv('out.csv', index = False, header = False)

# %%
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
df = pd.read_csv('ex3.csv')
# pick specific columns
df.to_csv('out.csv',  columns=['a','b'])

# %% [markdown]
# # Date

# %%
dates = pd.date_range(start='1/1/2000', periods=7, freq='ME')

# %%
import numpy as np
ts = pd.Series(np.arange(7), index = dates)
ts
# Out:
# 2000-01-31    0
# 2000-02-29    1
# 2000-03-31    2
# 2000-04-30    3
# 2000-05-31    4
# 2000-06-30    5
# 2000-07-31    6
# Freq: ME, dtype: int32

# %%
ts.to_csv('date.csv', header=False)
# !cat date.csv # only in linux
# !type date.csv
# Out:
# 2000-01-31,0
# 2000-02-29,1
# 2000-03-31,2
# 2000-04-30,3
# 2000-05-31,4
# 2000-06-30,5
# 2000-07-31,6

# %%
import csv
r = csv.reader(open('ex1.csv'))
# for i in r:
#     print(i)
list(r)
# Out:
# [['a', 'b', 'c', 'd', 'message'],
#  ['1', '2', '3', '4', 'hello'],
#  ['5', '6', '7', '8', 'world'],
#  ['9', '10', '11', '12', 'foo']]

# %%
r.line_num
# Out:
# 4

# %%
with open('ex1.csv') as f:
    r = list(csv.reader(f))
r
# Out:
# [['a', 'b', 'c', 'd', 'message'],
#  ['1', '2', '3', '4', 'hello'],
#  ['5', '6', '7', '8', 'world'],
#  ['9', '10', '11', '12', 'foo']]

# %%
header, val = r[0], r[1:]

# %%
dic = {h:v for h, v in zip(header, zip(*val))}
dic
# Out:
# {'a': ('1', '5', '9'),
#  'b': ('2', '6', '10'),
#  'c': ('3', '7', '11'),
#  'd': ('4', '8', '12'),
#  'message': ('hello', 'world', 'foo')}

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
r = json.loads(obj)
r
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
json.dumps(r)
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
pd.DataFrame(r['siblings'], columns=['name', 'age', 'pets'], index =['1', '2'])
# Out:
#     name  age                    pets
# 1  Scott   30            [Zeus, Zuko]
# 2  Katie   38  [Sixes, Stache, Cisco]

# %%
a = pd.read_json('a.json')
a
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(a.to_json())
a.to_json(orient='records')
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}
# '[{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]'

# %%
ht = pd.read_html('htm.html')
ht[0]
# Out:
#                              Bank Name             City  ST   CERT  \
# 0                          Allied Bank         Mulberry  AR     91
# 1         The Woodbury Banking Company         Woodbury  GA  11297
# 2               First CornerStone Bank  King of Prussia  PA  35312
# 3                   Trust Company Bank          Memphis  TN   9956
# 4           North Milwaukee State Bank        Milwaukee  WI  20364
# ..                                 ...              ...  ..    ...
# 542                 Superior Bank, FSB         Hinsdale  IL  32646
# 543                Malta National Bank            Malta  OH   6629
# 544    First Alliance Bank & Trust Co.       Manchester  NH  34264
# 545  National State Bank of Metropolis       Metropolis  IL   3815
# 546                   Bank of Honolulu         Honolulu  HI  21029
#
#                    Acquiring Institution        Closing Date  \
# 0                           Today's Bank  September 23, 2016
# ...

# %%
print(len(ht))
# Out:
# 1

# %%
tm = pd.to_datetime(ht[0]['Closing Date'])
tm.dt.year.value_counts()
# Out:
# Closing Date
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: count, dtype: int64

# %%
tm[0].date().day
# Out:
# 23

# %% [markdown]
# # Binary Format Data

# %%
data = pd.read_csv('ex1.csv')
data.to_pickle('pickle')
pd.read_pickle('pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# HDF5 Format
s = pd.HDFStore('my.h5')
s
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: my.h5

# %% [markdown]
# # Web API

# %%
import requests
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
res =res.json()
res
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/59660',
#   'id': 2496588305,
#   'node_id': 'PR_kwDOAA0YD8558Ms4',
#   'number': 59660,
#   'title': 'DOC: fix SA01,ES01 for pandas.NaT',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
# ...

# %%
res[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/59660/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/59660',
#  'id': 2496588305,
#  'node_id': 'PR_kwDOAA0YD8558Ms4',
#  'number': 59660,
#  'title': 'DOC: fix SA01,ES01 for pandas.NaT',
#  'user': {'login': 'tuhinsharma121',
#   'id': 6801780,
#   'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tuhinsharma121',
#   'html_url': 'https://github.com/tuhinsharma121',
#   'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
# ...

# %%
pd.DataFrame(res, columns=['number', 'title', 'labels', 'state'])
# Out:
#     number                                              title  \
# 0    59660                  DOC: fix SA01,ES01 for pandas.NaT
# 1    59659                   ENH: increase verbosity on error
# 2    59658  DOC: fix RT03,SA01,ES01 for pandas.MultiIndex....
# 3    59657  PERF: Melt 2x slower when future.infer_string ...
# 4    59656  BUG: arithmetic between datetime.timedelta sca...
# 5    59655  DOCS: fix docstring validation error for panda...
# 6    59654  expose `to_pandas_kwargs` in `read_parquet` wi...
# 7    59653  BUG: some cases of binary arithmetic between s...
# 8    59652  BUG: Pearson correlation outside expected rang...
# 9    59650        BUG: diff method incorrect on datetime64[s]
# 10   59649                                 increase verbosity
# 11   59648  TST: Add SparseArray _arith_method test to fai...
# 12   59647                PERF: CategoricalDtype.update_dtype
# 13   59646         BUG: Retain index when merging on an index
# ...
